# %%
import os
import random
import time
import vertexai
from vertexai import agent_engines

print("✅ Imports completed successfully")
# Out:
# ✅ Imports completed successfully

# %%
## Set your PROJECT_ID
PROJECT_ID = "gen-lang-client-0210165757"  # TODO: Replace with your project ID
os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID

if PROJECT_ID == "your-project-id" or not PROJECT_ID:
    raise ValueError("⚠️ Please replace 'your-project-id' with your actual Google Cloud Project ID.")

print(f"✅ Project ID set to: {PROJECT_ID}")
# Out:
# ✅ Project ID set to: gen-lang-client-0210165757
